# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Amal Radwan** Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy working with data.I also enjoy doing visualization and bringing numbers to life.

# %% [markdown]
# ##### The following code shows the ability of python to perform mathematics ( Press enter + shift )

# %%
1+1

# %% [markdown]
# ![image.png](attachment:image.png)
# ***
# ***
# **Data Scientist needed skills:**
# 1. Math & Stat.
# 2. Domain knowledge.
# 3. Programming and Database.
# 4. Communication and Visualization.
#
# ~~This line is striked~~
